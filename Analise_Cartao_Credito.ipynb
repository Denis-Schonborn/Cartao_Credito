# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
Cartao_Credito = pd.read_csv("Credit_Data.csv")

# %%
Cartao_Credito.head()
# Out:
#    ID   Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   1   14.891   3606     283      2   34         11    Male      No     Yes
# 1   2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2   3  104.593   7075     514      4   71         11    Male      No      No
# 3   4  148.924   9504     681      3   36         11  Female      No      No
# 4   5   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580
# 3      Asian      964
# 4  Caucasian      331

# %%
Cartao_Credito = Cartao_Credito.rename(columns = {"Income":"Renda", "Limit":"Limite_Cartao", "Rating":"Nota_Cliente", "Cards":"QTD.Cartao", "Age":"Idade", "Education":"Anos_Educacao", "Gender":"Genero", "Student":"Aluno", "Married":"Casado", "Ethnicity":"Etinia", "Balance":"Saldo_Conta"})

# %%
Cartao_Credito = Cartao_Credito.drop(columns = "ID")

# %%
Cartao_Credito.head()
# Out:
#      Renda  Limite_Cartao  Nota_Cliente  QTD.Cartao  Idade  Anos_Educacao  \
# 0   14.891           3606           283           2     34             11
# 1  106.025           6645           483           3     82             15
# 2  104.593           7075           514           4     71             11
# 3  148.924           9504           681           3     36             11
# 4   55.882           4897           357           2     68             16
#
#    Genero Aluno Casado     Etinia  Saldo_Conta
# 0    Male    No    Yes  Caucasian          333
# 1  Female   Yes    Yes      Asian          903
# 2    Male    No     No      Asian          580
# 3  Female    No     No      Asian          964
# 4    Male    No    Yes  Caucasian          331
